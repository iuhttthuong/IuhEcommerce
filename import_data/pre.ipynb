# %%
import sys
import os

# Thêm thư mục gốc (project/) vào sys.path
# Nếu __file__ không có (trong notebook), thay bằng:
sys.path.append(os.path.abspath(".."))

from services.products import ProductServices

# %%
import sys
from psycopg2.extras import execute_values
import json
import psycopg2
from datetime import datetime
from env import env

from import_data.tools import *

from models.sellers import SellerCreate, Seller
from models.brands import BrandCreate, Brand 
from models.categories import CategoryCreate, Category
from models.products import Product, ProductCreate
from models.warranties import Warranty, WarrantyCreate
from models.product_images import ProductImage, ProductImageCreate

# %%
error_log = []

# Connection details
db_params = {
    "dbname": env.DB_NAME,
    "user": env.DB_USER,
    "password": env.DB_PASSWORD,
    "host": env.DB_HOST,  
    "port": env.DB_PORT,  
}

# %%
# Read the JSON files
try:
    with open("../data/crawl_data_info_proper.json", "r", encoding="utf-8") as f:
        data_crawl = json.load(f)
except Exception as e:
    error_log.append(f"Error reading crawl data: {e}")
    data_crawl = []

try:
    with open("../data/product_data_info_proper.json", "r", encoding="utf-8") as f:
        data_product = json.load(f)
except Exception as e:
    error_log.append(f"Error reading product data: {e}")
    data_product = []

# %%
try:
    error_log = []
    conn = psycopg2.connect(**db_params)
    cursor = conn.cursor()

    cursor.execute("SELECT version();")
    db_version = cursor.fetchone()
    print(f"Connected to: {db_version}")


    print()
        
    def check_seller(seller_id):
        if not seller_id:
            return False
        cursor.execute("SELECT seller_id FROM sellers WHERE seller_id = %s", (seller_id,))
        return cursor.fetchone() is not None

    def add_seller(i):
        try:
            cursor.execute(
                """
                INSERT INTO sellers (seller_id, seller_name, seller_type, seller_link, seller_logo_url, seller_store_id,
                                    seller_is_best_store, is_seller, is_seller_in_chat_whitelist,
                                    is_offline_installment_supported, store_rating, created_at, updated_at)
                VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
                """,
                (
                    data_crawl[i].get("seller_id"),
                    data_product[i].get("current_seller").get("name"),
                    None,
                    data_product[i].get("current_seller").get("link"),
                    data_product[i].get("current_seller").get("logo"),
                    data_product[i].get("current_seller").get("store_id"),
                    None,
                    None,
                    data_product[i].get("is_seller_in_chat_whitelist"),
                    data_product[i] .get("current_seller").get("is_offline_installment_supported"),
                    None,
                    datetime.now(),
                    datetime.now()
                )   
            )
            conn.commit()
        except Exception as e:
            error_log.append(f"Error adding seller {data_crawl[i].get('seller_id')}: {e}")
            conn.rollback()

    def add_sellers():
        if not data_crawl or data_product:
            print("khong co du lieu")
            
        for i in range(len(data_product)):
            
            seller_id = data_crawl[i].get("seller_id")
            if seller_id and not check_seller(seller_id):
                add_seller(i)
            else:
                print(f"Seller {seller_id} already exists or is invalid.")

    def check_brand(brand_id):
        if not brand_id:
            return False
        cursor.execute("SELECT brand_id FROM brands WHERE brand_id = %s", (brand_id,))
        return cursor.fetchone() is not None

    def add_brand(i):
        try:
            cursor.execute(
                """
                INSERT INTO brands (brand_id, brand_name, brand_slug, brand_country)
                VALUES (%s, %s, %s, %s)
                """,
                (
                    data_product[i]['brand']["id"],
                    data_product[i]['brand']["name"],
                    data_product[i]['brand']["slug"],
                    get_attribute_value(data_product[i]["specifications"], "brand_country")
                )   
            )
            conn.commit()
        except Exception as e:
            error_log.append(f"Error adding brand {data_product[i].get('brand_id')}: {e}")
            conn.rollback()

    def add_brands():
        if not data_product:
            print("khong co du lieu")
            
        for i in range(len(data_product)):
            brand_id = data_product[i].get("brand", {}).get("id", None)
            if brand_id:
                if brand_id and not check_brand(brand_id):
                    add_brand(i)
                else:
                    print(f"Brand {brand_id} already exists or is invalid.")

    def check_category(category_id):
        if not category_id:
            return False
        cursor.execute("SELECT category_id FROM categories WHERE category_id = %s", (category_id,))
        return cursor.fetchone() is not None

    def add_category(data):
        try:
            category = CategoryCreate(**data)
            cursor.execute(
                """
                INSERT INTO categories (category_id, name, path)
                VALUES (%s, %s, %s)
                """,
                (
                    category.category_id if category.category_id not in (0, None) else 1,
                    category.name,
                    category.path
                )
            )
            conn.commit()
        except Exception as e:
            error_log.append(f"Error adding category {data.get('category_id')}: {e}")
            conn.rollback()

    def add_categories():
        if not data_product:
            print("khong co du lieu")
            
        for i in range(len(data_product)):
            
            cate_list = extract_category_info(data_product[i]['breadcrumbs']) 
            for data in cate_list:
                category_id = data['category_id']
                if category_id and not check_category(category_id):
                    add_category(data)
                else:
                    print(f"Category {category_id} already exists or is invalid.")
    def check_product(product_id):
        if not product_id:
            return False
        cursor.execute("SELECT product_id FROM products WHERE product_id = %s", (product_id,))
        return cursor.fetchone() is not None      

    def add_product(i):
        try:
            quantity_value = data_product[i].get("quantity_sold", {})
            if isinstance(quantity_value, dict):
                quantity_sold = quantity_value.get("value", 0)
            else:
                quantity_sold = 0


            cursor.execute(
                """
                INSERT INTO products (product_id, name, product_short_url, description, short_description,
                                    price, original_price, discount, discount_rate, sku, review_text,
                                    quantity_sold, rating_average, review_count, order_count,
                                    favourite_count, thumbnail_url, category_id, brand_id,
                                    seller_id, shippable, availability, created_at, updated_at)
                VALUES (%s, %s, %s, %s, %s,
                        # %s, %s, %s, %s, %s,
                        # %s, %s, %s, %s, %s,
                        # %s, %s, %s, %s,
                        # %s, %s, %s, %s, %s)
                """,
                (
                    data_product[i]["id"],
                    data_product[i]["name"],
                    data_product[i]["short_url"],
                    data_product[i]["description"],
                    data_product[i]["short_description"],
                    data_product[i]["price"],
                    data_product[i]["original_price"],
                    data_product[i]["discount"],
                    data_product[i]["discount_rate"],
                    data_product[i]["sku"],
                    data_product[i]["review_text"],
                    quantity_sold,
                    data_product[i]["rating_average"],
                    data_product[i]["review_count"],
                    0,
                    data_product[i]["favourite_count"],
                    data_product[i]["thumbnail_url"],
                    get_last_category_id(extract_category_info(data_product[i]['breadcrumbs'])),
                    data_product[i]['brand']["id"],
                    data_crawl[i].get("seller_id"),
                    data_crawl[i]['shippable'],
                    data_crawl[i]['availability'],
                    datetime.now(),
                    datetime.now()
                )
            )
            conn.commit()
        except Exception as e:
            error_log.append(f"Error adding product {data_product[i].get('product_id')}: {e}")
            conn.rollback()

    def add_products():
        if not data_product:
            print("khong co du lieu")
        count = 0
        for i in range(len(data_product)):
            
            product_id = data_product[i]["id"]
            brand_id = data_product[i].get("brand", {}).get("id", None)
            if brand_id:
                add_product(i)
                count += 1
                print(f"Product {product_id} added successfully.")
            else:
                print(f"Product {product_id} already exists or is invalid.")
        print(f"Total products added: {count}")

    def check_warranty(warranty_id):
        if not warranty_id:
            return False
        cursor.execute("SELECT product_id FROM warranties WHERE product_id = %s", (warranty_id,))
        return cursor.fetchone() is not None

    def add_warranty(i):    
        try:
            cursor.execute(
                """
                INSERT INTO warranties (product_id, warranty_location, warranty_period, warranty_form,
                                        warranty_url, return_policy)
                VALUES (%s, %s, %s, %s, %s, %s)
                """,
                (
                    data_product[i]["id"],
                    get_value_by_name(data_brand[i]["warranty_info"], "Nơi bảo hành"),    
                    get_value_by_name(data_brand[i]["warranty_info"], "Thời gian bảo hành"),
                    get_value_by_name(data_brand[i]["warranty_info"], "Hình thức bảo hành"),
                    extract_url(data_brand[i]["warranty_info"]),
                    (lambda d: sum([b.get('content', []) for b in d.get('body', [])], []))(data_brand[i]["return_policy"])
                )
            )
            conn.commit()
        except Exception as e:
            error_log.append(f"Error adding warranty {data_product[i].get('product_id')}: {e}")
            conn.rollback()

    def add_warranties():  
        if not data_product:
            print("khong co du lieu")

        for i in range(len(data_product)):

            warranty_id = data_product[i]["id"]
            if warranty_id and not check_warrranty(warranty_id):
                add_warranty(i)
                print(f"Warranty {warranty_id} added successfully.")
            else:
                print(f"Warranty {warranty_id} already exists or is invalid.")

            print("khong co du lieu")
            
        for i in range(1000):
            
            warranty_id = data_product[i]["id"]
            if warranty_id and not check_warrranty(warranty_id):
                add_warranty(i)
                print(f"Warranty {warranty_id} added successfully.")
            else:
                print(f"Warranty {warranty_id} already exists or is invalid.")

                
    def check_product_image(product_id):
        if not product_id:
            return False
        cursor.execute("SELECT product_id FROM product_images WHERE product_id = %s", (product_id,))
        return cursor.fetchone() is not None
    def add_product_image(i):
        try:
            product = data_product[i]
            product_id = product.get("id")
            product_images = product.get("images", [])

            for pi in product_images:
                cursor.execute(
                    """
                    INSERT INTO product_images (product_id, base_url, large_url, medium_url)
                    VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
                    """,
                    (
                        product_id,
                        pi["base_url"],
                        pi["large_url"],
                        pi["medium_url"],
                        pi["is_gallery"]
                    )   
                )
            conn.commit()

        except Exception as e:
            error_log.append(f"Error adding product image for product {id}: {e}")
            conn.rollback()

    def add_product_images():
        if not data_product:
            print("khong co du lieu")
            
        for i in range(len(data_product)):
            
            product_id = data_product[i]["id"]
            if product_id and not check_product_image(product_id):
                add_product_image(i)
                print(f"Product image {product_id} added successfully.")
            else:
                print(f"Product image {product_id} already exists or is invalid.")  

    def check_inventory(product_id):
        if not product_id:
            return False
        cursor.execute("SELECT product_id FROM inventories WHERE product_id = %s", (product_id,))
        return cursor.fetchone() is not None

    def add_inventory(i):
        try:
            cursor.execute(
                """
                INSERT INTO inventories (product_id, product_virtual_type, fulfillment_type)
                VALUES (%s, %s, %s)
                """,
                (
                    data_product[i]["id"],
                    data_product[i]["inventory"]["product_virtual_type"],
                    data_product[i]["inventory"]["fulfillment_type"]
                )
            )
            conn.commit()
        except Exception as e:
            error_log.append(f"Error adding inventory {data_product[i].get('product_id')}: {e}")
            conn.rollback()

    def add_inventories():
        if not data_product:
            print("khong co du lieu")
            
        for i in range(len(data_product)):
            
            product_id = data_product[i]["id"]
            if product_id and not check_inventory(product_id):
                add_inventory(i)
                print(f"Inventory {product_id} added successfully.")
            else:
                print(f"Inventory {product_id} already exists or is invalid.")
            



    add_sellers()
    add_brands()
    add_categories()
    add_products()
    # add_warranties() không có dữ liệu
    add_product_images()
    add_inventories()
    
except Exception as e:
    error_log.append(f"Database connection error: {e}")
finally:
    if 'cursor' in locals():
        cursor.close()
    if 'conn' in locals():
        conn.close()
if error_log:
    print("Errors occurred during the process:")
    for error in error_log:
        print(error)
# Out:
# Errors occurred during the process:
# Database connection error: name 'psycopg2' is not defined

# %%
data_product[1]
# Out:
# {'services_and_promotions': [],
#  'productset_group_name': '',
#  'review_text': 'Chưa có đánh giá',
#  'data_version': 3300,
#  'gift_item_title': '0 quà tặng kèm',
#  'return_policy': {'body': [{'label': '',
#     'content': ['Sản phẩm không đúng cam kết (lỗi kỹ thuật, giao sai/thiếu, bể vỡ…)',
#      'Không hỗ trợ lý do đổi ý.']}],
#   'cta': {'link': 'https://hotro.tiki.vn/s/article/chinh-sach-doi-tra-san-pham',
#    'text_button': 'Tìm hiểu thêm'},
#   'title': 'Đổi trả miễn phí trong 30 ngày'},
#  'favourite_count': 0,
#  'other_sellers': [],
#  'meta_title': '',
#  'id': 253392247,
#  'warranty_info': [],
#  'inventory_status': 'available',
#  'is_gift_card': False,
#  'original_price': 100000,
#  'thumbnail_url': 'https://salt.tikicdn.com/cache/280x280/ts/product/ea/35/ab/4b5737e0e4387e34a1024f412ed4cd10.jpg',
#  'short_description': 'HƯỚNG DẪN MUA HÀNG:- Đơn hàng sau khi được thanh toán thành công, ecode sẽ được gửi đến E.m.a.i.l quý khách đã nhập tại trang mua hàng.Khách hàng vui lòng xuất trình đúng nhận diện cho nhân viên kiể...',
#  'stock_item': {'max_sale_qty': 1000,
#   'min_sale_qty': 1,
#   'preorder_date': None,
#   'qty': 1000},
#  'day_ago_created': 735,
#  'url_key': 'evoucher-tiniworld-standard-ngay-thuong-ap-dung-tai-cac-trung-tam-tiniworld-co-gia-ve-vao-cong-ngay-thuong-100-000-vnd-p253392247',
#  'is_tier_pricing_eligible': False,
#  'promitions': [],
#  'inventory': {'product_virtual_type': 'evoucher',
#   'fulfillment_type': 'instant_delivery'},
#  'salable_type': None,
#  'master_id': 253392247,
#  'list_price': 100000,
#  'discount': 5000,
#  'is_fresh': False,
#  'discount_rate': 5,
#  'name': 'Vé cổng điện tử tiNiWorld STANDARD NGÀY THƯỜNG áp dụng tại các trung tâm tiNiWorld có giá vé vào cổng 100.000 VNĐ',
#  'specifications': [{'name': 'Thông tin chung',
#    'attributes': [{'code': 'how_to_use',
#      'name': 'Hướng dẫn sử dụng',
#      'value': '<p>⛔\xa0LƯU\xa0Ý\xa0KHI\xa0SỬ\xa0DỤNG\xa0EVOUCHER:</p>\n<p>&#x1f538;Khách\xa0hàng\xa0có\xa0trách\xa0nhiệm\xa0bảo\xa0mật\xa0thông\xa0tin\xa0Evoucher\xa0sau\xa0khi\xa0đặt\xa0mua.\xa0tiNi\xa0sẽ\xa0không\xa0chịu\xa0trách\xa0nhiệm\xa0hoàn\xa0trả\xa0các\xa0mã\xa0thẻ\xa0bị\xa0mất\xa0hoặc\xa0ở\xa0trạng\xa0thái\xa0&#34;Đã\xa0sử\xa0dụng&#34;\xa0với\xa0bất\xa0kỳ\xa0lý\xa0do\xa0gì,\xa0tiNi\xa0có\xa0quyền\xa0sửa\xa0chữa\xa0hoặc\xa0thay\xa0đổi\xa0điều\xa0khoản\xa0và\xa0điều\xa0kiện\xa0sử\xa0dụng\xa0mà\xa0không\xa0thông\xa0báo\xa0trước.</p>\n<p>&#x1f538;Khi\xa0mua\xa0hàng\xa0trên\xa0các\xa0sàn\xa0TMĐT\xa0tiNi\xa0chưa\xa0hỗ\xa0trợ\xa0tích\xa0lũy\xa0chi\xa0tiêu\xa0và\xa0tích\xa0lũy\xa0điểm\xa0đối\xa0với\xa0khách\xa0hàng\xa0có\xa0thẻ\xa0thành\xa0viên\xa0tiNi.</p>\n<p>&#x1f538;Thời\xa0hạn\xa0ghi\xa0nhận\xa0thông\xa0tin\xa0và\xa0hỗ\xa0trợ\xa0trong\xa0vòng\xa03\xa0ngày\xa0kể\xa0từ\xa0ngày\xa0phát\xa0sinh\xa0đơn\xa0hàng.</p>\n<p>&#x1f538;Sau khi nhận được Evoucher, khách hàng cần sử dụng trong vòng 30 ngày tính từ ngày thanh toán đơn hàng thành công</p>\n<p>&#x1f538;Trường hợp quý khách cần hỗ trợ gửi lại mã E-voucher vui lòng liên hệ trong vòng 3 ngày kể từ ngày phát sinh đơn hàng và hạn sử dụng sẽ được ghi nhận kể từ lần thanh toán đơn hàng thành công (không bao gồm ngày gửi lại mã E-voucher)</p>\n<p>&#x1f538;Để\xa0đảm\xa0bảo\xa0an\xa0toàn\xa0và\xa0vệ\xa0sinh,\xa0tất\xa0cả\xa0các\xa0bé\xa0bắt\xa0buộc\xa0phải\xa0mang\xa0vớ\xa0chống\xa0trượt\xa0khi\xa0vào\xa0tiNiWorld.</p>\n<p>&#x1f538;\xa0Nhấn\xa0&#34;Đặt\xa0hàng&#34;\xa0đồng\xa0nghĩa\xa0với\xa0việc\xa0bạn\xa0đồng\xa0ý\xa0tuần\xa0theo\xa0Quy\xa0định\xa0của\xa0tiNiWorld.</p>\n<p>&#x1f538; Không sử dụng email Công ty / Icloud để nhận Evoucher.\xa0</p>\n<p>\xa0</p>'},
#     {'code': 'dac_diem_noi_bat',
#      'name': 'Đặc điểm nổi bật',
#      'value': '<p><strong><span style="color:#333333;background-color:#ffffff">QUÝ KHÁCH VUI LÒNG THAM KHẢO DANH SÁCH TRUNG TÂM ÁP DỤNG NHÉ!!!!</span></strong></p>\n<p><img src="https://salt.tikicdn.com/ts/tmp/9a/4c/28/b9e0e187d90600201099b8c26f4b90bc.png" alt="" width="750" height="750" /></p>\n<p>Thời gian áp dụng loại vé Standard: từ Thứ 2 -&gt; Thứ 6 (không áp dụng cho các ngày cuối tuần/Lễ, Tết...)</p>\n<p>\xa0</p>\n<p>\xa0</p>\n<p>\xa0</p>'},
#     {'code': 'dieu_kien_su_dung',
#      'name': 'Điều kiện sử dụng',
#      'value': '<p class="irIKAp">GIỚI THIỆU:</p>\n<p class="irIKAp">Được xây dựng và phát triển dựa trên mô hình kết hợp giáo dục &amp; giải trí hiện đại và khoa học dành cho trẻ em từ 0-12 tuổi, tiNiWorld tự hào là chuỗi trung tâm “Giáo –Trí” hàng đầu tại Việt Nam.</p>\n<p class="irIKAp">Hệ thống các trung tâm tiNiWorld trải dài khắp mọi nơi tại Việt Nam, ở các thành phố trọng điểm Hồ Chí Minh, Bình Dương, Hà Nội và các thành phố lớn khác như: Cần Thơ,Vũng Tàu, Đà Nẵng, Hải Phòng…Tại tiNiWorld, bất cứ góc chơi nào cũng được xây dựng theo đúng tiêu chuẩn quốc tếvới đầy đủ đồ chơi từ các thương hiệu nổi tiếng hướng đến mục tiêu cuối cùng là mang đến những giây phút vui chơi thú vị, góp phần mang đến sự phát triển toàn diện cho bé như thể chất, trí tuệ, mỹ thuật, cảm xúc và khả năng giao tiếp xã hội.</p>\n<p class="irIKAp">Ngoài các góc chơi như khu vận động, sàn nhún trampoline, nhà banh, hồ cát, phòng chơi siêu anh hùng cho bé trai, phòng hoá thân công chúa cho bé gái, khu vực đồ chơi gỗ dành cho mẫu giáo, khu mỹ thuật … tiNiWorld còn có các lớp chơi đặc biệt kết hợp các thương hiệu đối tác như lớp nấu ăn đặc biệt, tập thể dục cùng tiNiFit kết hợp với thương hiệu Gym California.\xa0</p>\n<p class="irIKAp">*Vé cổng sẽ bao gồm nhiều góc chơi miễn phí như: nhà banh, nhà cát, khu vực juNo, teRa, Toddler Garden, Baby box,…....</p>\n<p class="irIKAp"><strong>**Phụ huynh phải trả thêm chi phí khi bé chơi máy game, mua vật dụng tô màu, mua đồ ăn/nước uống. Bên cạnh đó tiNiWorld còn là nơi hoàn hảo để tổ chức sinh nhật và các sự kiện thiếu nhi như Tết Trung thu và Ngày Quốc tế Thiếu nhi.</strong></p>\n<p class="irIKAp"><strong>***<span style="background-color:#ffff00;color:#ff0000"><span style="color:#333333;background-color:#ffffff">Để đảm bảo an toàn và vệ sinh, tất cả các bé bắt buộc phải mang vớ chống trượt khi vào tiNiWorld.</span></span></strong></p>\n<p>Lưu ý:\xa0</p>\n<ul><li>Khi mua hàng trên các sàn TMĐT tiNi chưa hỗ trợ tích lũy chi tiêu và tích lũy điểm đối với khách hàng có thẻ thành viên tiNi</li><li>Thời hạn ghi nhận thông tin và hỗ trợ trong vòng 3 ngày kể từ ngày phát sinh đơn hàng.</li><li>Không sử dụng email Công ty để nhận Evoucher.</li></ul>\n<p class="irIKAp">→ Hotline: 190063 63 28</p>'},
#     {'code': 'dia_chi_su_dung',
#      'name': 'Địa chỉ sử dụng',
#      'value': '2307,1070,1038'}]},
#   {'name': 'Cách sử dụng',
#    'attributes': [{'code': 'how_to_use',
#      'name': 'Hướng dẫn sử dụng',
#      'value': '<p>⛔\xa0LƯU\xa0Ý\xa0KHI\xa0SỬ\xa0DỤNG\xa0EVOUCHER:</p>\n<p>&#x1f538;Khách\xa0hàng\xa0có\xa0trách\xa0nhiệm\xa0bảo\xa0mật\xa0thông\xa0tin\xa0Evoucher\xa0sau\xa0khi\xa0đặt\xa0mua.\xa0tiNi\xa0sẽ\xa0không\xa0chịu\xa0trách\xa0nhiệm\xa0hoàn\xa0trả\xa0các\xa0mã\xa0thẻ\xa0bị\xa0mất\xa0hoặc\xa0ở\xa0trạng\xa0thái\xa0&#34;Đã\xa0sử\xa0dụng&#34;\xa0với\xa0bất\xa0kỳ\xa0lý\xa0do\xa0gì,\xa0tiNi\xa0có\xa0quyền\xa0sửa\xa0chữa\xa0hoặc\xa0thay\xa0đổi\xa0điều\xa0khoản\xa0và\xa0điều\xa0kiện\xa0sử\xa0dụng\xa0mà\xa0không\xa0thông\xa0báo\xa0trước.</p>\n<p>&#x1f538;Khi\xa0mua\xa0hàng\xa0trên\xa0các\xa0sàn\xa0TMĐT\xa0tiNi\xa0chưa\xa0hỗ\xa0trợ\xa0tích\xa0lũy\xa0chi\xa0tiêu\xa0và\xa0tích\xa0lũy\xa0điểm\xa0đối\xa0với\xa0khách\xa0hàng\xa0có\xa0thẻ\xa0thành\xa0viên\xa0tiNi.</p>\n<p>&#x1f538;Thời\xa0hạn\xa0ghi\xa0nhận\xa0thông\xa0tin\xa0và\xa0hỗ\xa0trợ\xa0trong\xa0vòng\xa03\xa0ngày\xa0kể\xa0từ\xa0ngày\xa0phát\xa0sinh\xa0đơn\xa0hàng.</p>\n<p>&#x1f538;Sau khi nhận được Evoucher, khách hàng cần sử dụng trong vòng 30 ngày tính từ ngày thanh toán đơn hàng thành công</p>\n<p>&#x1f538;Trường hợp quý khách cần hỗ trợ gửi lại mã E-voucher vui lòng liên hệ trong vòng 3 ngày kể từ ngày phát sinh đơn hàng và hạn sử dụng sẽ được ghi nhận kể từ lần thanh toán đơn hàng thành công (không bao gồm ngày gửi lại mã E-voucher)</p>\n<p>&#x1f538;Để\xa0đảm\xa0bảo\xa0an\xa0toàn\xa0và\xa0vệ\xa0sinh,\xa0tất\xa0cả\xa0các\xa0bé\xa0bắt\xa0buộc\xa0phải\xa0mang\xa0vớ\xa0chống\xa0trượt\xa0khi\xa0vào\xa0tiNiWorld.</p>\n<p>&#x1f538;\xa0Nhấn\xa0&#34;Đặt\xa0hàng&#34;\xa0đồng\xa0nghĩa\xa0với\xa0việc\xa0bạn\xa0đồng\xa0ý\xa0tuần\xa0theo\xa0Quy\xa0định\xa0của\xa0tiNiWorld.</p>\n<p>&#x1f538; Không sử dụng email Công ty / Icloud để nhận Evoucher.\xa0</p>\n<p>\xa0</p>'}]},
#   {'name': 'Thời hạn sử dụng',
#    'attributes': [{'code': 'expiry_date',
#      'name': 'Thời hạn sử dụng',
#      'value': 'Áp dụng đến hết ngày 31/05/2025'}]}],
#  'categories': {'id': 11329, 'name': 'Vui chơi - Giải trí', 'is_leaf': True},
#  'return_and_exchange_policy': 'Đổi trả trong<br><b>30 ngày</b><br>nếu sp lỗi.',
#  'review_count': 0,
#  'sku': '9425456452236',
#  'benefits': [{'icon': 'https://salt.tikicdn.com/ts/upload/d8/c7/a5/1cd5bd2f27f9bd74b2c340b8e27c4d82.png',
#    'text': 'Đổi trả miễn phí trong 30 ngày',
#    'sub_text': [],
#    'cta': {'text': 'Chi tiết', 'type': 'open_policy_return_modal'}}],
#  'description': '<p>Hạn sử dụng: 2025-05-31 00:00:00</p><p class="irIKAp"><strong>HƯỚNG DẪN MUA HÀNG:</strong></p>\n<p class="irIKAp">- Đơn hàng sau khi được thanh toán thành công, ecode sẽ được gửi đến E.m.a.i.l quý khách đã nhập tại trang mua hàng.</p>\n<p class="irIKAp">Khách hàng vui lòng xuất trình đúng nhận diện cho nhân viên kiểm soát cổng để sử dụng voucher (không chấp nhận các danh sách mã voucher viết tay, in ấn ra giấy).</p>\n<p class="irIKAp">Không có giántrị quy đổi thành tiền mặt, không được hoàn trả tiền thừa. Mã voucher đã mua không hỗ trợ hoàn hủy đổi trả dưới mọi hình thức.</p>\n<p class="irIKAp">Một voucher tương đương 01 vé/ áp dụng cho 1 bé và 1 người lớn, chỉ được sử dụng 01 lần, có thể áp dụng được nhiều voucher cho 01 đơn hàng.</p>\n<p class="irIKAp">Phụ thu 20.000 cho người lớn thứ 2.</p>\n<p class="irIKAp">Khách hàng có trách nhiệm bảo mật thông tin Ecode sau khi đặt mua. tiNi sẽ không chịu trách nhiệm hoàn trả các mã thẻ bị mất hoặc ở trạng thái "Đ..ã sử dụng" với bất kỳ lý do gì. tiNi có quyền sửa chữa hoặc thay đổi điều khoản và điều kiện sử dụng mà không thông báo trước.</p>',
#  'product_links': [],
#  'is_seller_in_chat_whitelist': True,
#  'seller': None,
#  'tracking_info': {'amplitude': {'is_authentic': False,
#    'is_freeship_xtra': False,
#    'is_hero': False,
#    'is_top_brand': False,
#    'return_reason': 'defective_product'}},
#  'has_buynow': True,
#  'is_baby_milk': False,
#  'warranty_policy': None,
#  'images': [{'base_url': 'https://salt.tikicdn.com/ts/product/ea/35/ab/4b5737e0e4387e34a1024f412ed4cd10.jpg',
#    'is_gallery': True,
#    'label': None,
#    'large_url': 'https://salt.tikicdn.com/cache/w1200/ts/product/ea/35/ab/4b5737e0e4387e34a1024f412ed4cd10.jpg',
#    'medium_url': 'https://salt.tikicdn.com/cache/w300/ts/product/ea/35/ab/4b5737e0e4387e34a1024f412ed4cd10.jpg',
#    'position': None,
#    'small_url': 'https://salt.tikicdn.com/cache/200x280/ts/product/ea/35/ab/4b5737e0e4387e34a1024f412ed4cd10.jpg',
#    'thumbnail_url': 'https://salt.tikicdn.com/cache/200x280/ts/product/ea/35/ab/4b5737e0e4387e34a1024f412ed4cd10.jpg'},
#   {'base_url': 'https://salt.tikicdn.com/ts/product/9a/4c/28/b890c19e4f2adb29c10b134b4c19540c.png',
#    'is_gallery': True,
#    'label': None,
#    'large_url': 'https://salt.tikicdn.com/cache/w1200/ts/product/9a/4c/28/b890c19e4f2adb29c10b134b4c19540c.png',
#    'medium_url': 'https://salt.tikicdn.com/cache/w300/ts/product/9a/4c/28/b890c19e4f2adb29c10b134b4c19540c.png',
#    'position': None,
#    'small_url': 'https://salt.tikicdn.com/cache/200x280/ts/product/9a/4c/28/b890c19e4f2adb29c10b134b4c19540c.png',
#    'thumbnail_url': 'https://salt.tikicdn.com/cache/200x280/ts/product/9a/4c/28/b890c19e4f2adb29c10b134b4c19540c.png'},
#   {'base_url': 'https://salt.tikicdn.com/ts/product/c8/c0/99/81bb8aa46a923f22ccdb7039f1863dd6.jpg',
#    'is_gallery': True,
#    'label': None,
#    'large_url': 'https://salt.tikicdn.com/cache/w1200/ts/product/c8/c0/99/81bb8aa46a923f22ccdb7039f1863dd6.jpg',
#    'medium_url': 'https://salt.tikicdn.com/cache/w300/ts/product/c8/c0/99/81bb8aa46a923f22ccdb7039f1863dd6.jpg',
#    'position': None,
#    'small_url': 'https://salt.tikicdn.com/cache/200x280/ts/product/c8/c0/99/81bb8aa46a923f22ccdb7039f1863dd6.jpg',
#    'thumbnail_url': 'https://salt.tikicdn.com/cache/200x280/ts/product/c8/c0/99/81bb8aa46a923f22ccdb7039f1863dd6.jpg'},
#   {'base_url': 'https://salt.tikicdn.com/ts/product/e8/f0/ae/c78f614235c126155c1be36401263d7c.jpg',
#    'is_gallery': True,
#    'label': None,
#    'large_url': 'https://salt.tikicdn.com/cache/w1200/ts/product/e8/f0/ae/c78f614235c126155c1be36401263d7c.jpg',
#    'medium_url': 'https://salt.tikicdn.com/cache/w300/ts/product/e8/f0/ae/c78f614235c126155c1be36401263d7c.jpg',
#    'position': None,
#    'small_url': 'https://salt.tikicdn.com/cache/200x280/ts/product/e8/f0/ae/c78f614235c126155c1be36401263d7c.jpg',
#    'thumbnail_url': 'https://salt.tikicdn.com/cache/200x280/ts/product/e8/f0/ae/c78f614235c126155c1be36401263d7c.jpg'},
#   {'base_url': 'https://salt.tikicdn.com/ts/product/00/15/8f/29574a4b6a17f230b7b414cc53a6f354.jpg',
#    'is_gallery': True,
#    'label': None,
#    'large_url': 'https://salt.tikicdn.com/cache/w1200/ts/product/00/15/8f/29574a4b6a17f230b7b414cc53a6f354.jpg',
#    'medium_url': 'https://salt.tikicdn.com/cache/w300/ts/product/00/15/8f/29574a4b6a17f230b7b414cc53a6f354.jpg',
#    'position': None,
#    'small_url': 'https://salt.tikicdn.com/cache/200x280/ts/product/00/15/8f/29574a4b6a17f230b7b414cc53a6f354.jpg',
#    'thumbnail_url': 'https://salt.tikicdn.com/cache/200x280/ts/product/00/15/8f/29574a4b6a17f230b7b414cc53a6f354.jpg'},
#   {'base_url': 'https://salt.tikicdn.com/ts/product/b7/28/88/936b1abec6bc6b70af02baa749868fe2.jpg',
#    'is_gallery': True,
#    'label': None,
#    'large_url': 'https://salt.tikicdn.com/cache/w1200/ts/product/b7/28/88/936b1abec6bc6b70af02baa749868fe2.jpg',
#    'medium_url': 'https://salt.tikicdn.com/cache/w300/ts/product/b7/28/88/936b1abec6bc6b70af02baa749868fe2.jpg',
#    'position': None,
#    'small_url': 'https://salt.tikicdn.com/cache/200x280/ts/product/b7/28/88/936b1abec6bc6b70af02baa749868fe2.jpg',
#    'thumbnail_url': 'https://salt.tikicdn.com/cache/200x280/ts/product/b7/28/88/936b1abec6bc6b70af02baa749868fe2.jpg'},
#   {'base_url': 'https://salt.tikicdn.com/ts/product/13/89/b1/6605efcc6ea12257756ab6cb25f6b6ca.jpg',
#    'is_gallery': True,
#    'label': None,
#    'large_url': 'https://salt.tikicdn.com/cache/w1200/ts/product/13/89/b1/6605efcc6ea12257756ab6cb25f6b6ca.jpg',
#    'medium_url': 'https://salt.tikicdn.com/cache/w300/ts/product/13/89/b1/6605efcc6ea12257756ab6cb25f6b6ca.jpg',
#    'position': None,
#    'small_url': 'https://salt.tikicdn.com/cache/200x280/ts/product/13/89/b1/6605efcc6ea12257756ab6cb25f6b6ca.jpg',
#    'thumbnail_url': 'https://salt.tikicdn.com/cache/200x280/ts/product/13/89/b1/6605efcc6ea12257756ab6cb25f6b6ca.jpg'},
#   {'base_url': 'https://salt.tikicdn.com/ts/product/3f/34/29/971bdbd6c91b71b95747808564849407.jpg',
#    'is_gallery': True,
#    'label': None,
#    'large_url': 'https://salt.tikicdn.com/cache/w1200/ts/product/3f/34/29/971bdbd6c91b71b95747808564849407.jpg',
#    'medium_url': 'https://salt.tikicdn.com/cache/w300/ts/product/3f/34/29/971bdbd6c91b71b95747808564849407.jpg',
#    'position': None,
#    'small_url': 'https://salt.tikicdn.com/cache/200x280/ts/product/3f/34/29/971bdbd6c91b71b95747808564849407.jpg',
#    'thumbnail_url': 'https://salt.tikicdn.com/cache/200x280/ts/product/3f/34/29/971bdbd6c91b71b95747808564849407.jpg'},
#   {'base_url': 'https://salt.tikicdn.com/ts/product/4c/71/49/ee2a40cfe272dc452195f7eb6b2687e1.png',
#    'is_gallery': True,
#    'label': None,
#    'large_url': 'https://salt.tikicdn.com/cache/w1200/ts/product/4c/71/49/ee2a40cfe272dc452195f7eb6b2687e1.png',
#    'medium_url': 'https://salt.tikicdn.com/cache/w300/ts/product/4c/71/49/ee2a40cfe272dc452195f7eb6b2687e1.png',
#    'position': None,
#    'small_url': 'https://salt.tikicdn.com/cache/200x280/ts/product/4c/71/49/ee2a40cfe272dc452195f7eb6b2687e1.png',
#    'thumbnail_url': 'https://salt.tikicdn.com/cache/200x280/ts/product/4c/71/49/ee2a40cfe272dc452195f7eb6b2687e1.png'}],
#  'is_flower': False,
#  'price': 95000,
#  'breadcrumbs': [{'url': '/voucher-dich-vu/c11312',
#    'name': 'Voucher - Dịch vụ',
#    'category_id': 11312},
#   {'url': '/su-kien-giai-tri/c11327',
#    'name': 'Sự kiện - Giải trí',
#    'category_id': 11327},
#   {'url': '/vui-choi-giai-tri/c11329',
#    'name': 'Vui chơi - Giải trí',
#    'category_id': 11329},
#   {'url': 'https://tiki.vn/evoucher-tiniworld-standard-ngay-thuong-ap-dung-tai-cac-trung-tam-tiniworld-co-gia-ve-vao-cong-ngay-thuong-100-000-vnd-p253392247.html',
#    'name': 'Vé cổng điện tử tiNiWorld STANDARD NGÀY THƯỜNG áp dụng tại các trung tâm tiNiWorld có giá vé vào cổng 100.000 VNĐ',
#    'category_id': 0}],
#  'meta_description': '',
#  'rating_average': 0,
#  'is_tier_pricing_available': False,
#  'is_acoholic_drink': False,
#  'meta_keywords': '',
#  'all_time_quantity_sold': 12,
#  'has_ebook': False,
#  'short_url': 'https://tiki.vn/product-p253392247.html?spid=253392248',
#  'current_seller': {'id': 44859,
#   'sku': '9328882521291',
#   'name': 'TiNi Official Store',
#   'link': 'https://tiki.vn/cua-hang/tini-official-store',
#   'logo': '5b/83/11/0bf95457f4b7e4d1cf1da407bbf4bf97.jpg',
#   'price': 95000,
#   'product_id': '253392248',
#   'store_id': 43358,
#   'is_best_store': False,
#   'is_offline_installment_supported': None},
#  'quantity_sold': {'text': 'Đã bán 12', 'value': 12},
#  'inventory_type': 'backorder',
#  'installment_info_v2': None}
